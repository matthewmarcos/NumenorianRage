# %% [markdown]
# # Numenorian Rage
#
# This project explores the Numenorian Kings and their descendants.

# %%
import csv
import pandas

# %%
headers = [
    'url',
    'referrer',
    'name',
    'other_names',
    'titles',
    'birth_year',
    'rule_start',
    'rule_end',
    'death_year',
    'notable_for'
]

# %%
kings_table = pandas.read_csv('kings.psv', sep='|', names=headers)
kings_table.head(10)
# Out:
#                                                  url  \
# 0               http://tolkiengateway.net/wiki/Elros
# 1             http://tolkiengateway.net/wiki/Elendil
# 2            http://tolkiengateway.net/wiki/Vardamir
# 3      http://tolkiengateway.net/wiki/Tind%C3%B3miel
# 4           http://tolkiengateway.net/wiki/Atanalcar
# 5           http://tolkiengateway.net/wiki/Manwendil
# 6        http://tolkiengateway.net/wiki/An%C3%A1rion
# 7            http://tolkiengateway.net/wiki/Nolondil
# 8  http://tolkiengateway.net/wiki/Aulendil_(son_o...
# 9             http://tolkiengateway.net/wiki/Isildur
#
#                                      referrer          name   other_names  \
# 0                                         NaN         Elros  Tar-Minyatur
# 1                                         NaN       Elendil      Nimruzîr
# 2     b'http://tolkiengateway.net/wiki/Elros'  Tar-Vardamir       Nólimon
# 3     b'http://tolkiengateway.net/wiki/Elros'     Tindómiel           NaN
# ...

# %%
numenorian_kings_df = kings_table[kings_table['titles']=='King of Númenor']
# numenorian_kings_df.sort_values('birth_year').head()

# %%
gondorian_kings_df = kings_table[kings_table['titles']=='King of Gondor']
# gondorian_kings_df.sort_values('birth_year').head()

# %%
arnorian_kings_df = kings_table[
    (kings_table['titles']=='King of Arnor')|(kings_table['titles']=='King of Arthedain')
]

arnorian_kings_df.sort_values('rule_start').head(20)
# Out:
#                                                    url  \
# 18   http://tolkiengateway.net/wiki/Valandil_(King_...
# 60               http://tolkiengateway.net/wiki/Mallor
# 63            http://tolkiengateway.net/wiki/Celepharn
# 66          http://tolkiengateway.net/wiki/Celebrindor
# 69             http://tolkiengateway.net/wiki/Malvegil
# 73            http://tolkiengateway.net/wiki/Argeleb_I
# 79            http://tolkiengateway.net/wiki/Arveleg_I
# 83              http://tolkiengateway.net/wiki/Araphor
# 86           http://tolkiengateway.net/wiki/Argeleb_II
# 89              http://tolkiengateway.net/wiki/Arvegil
# 92           http://tolkiengateway.net/wiki/Arveleg_II
# 94               http://tolkiengateway.net/wiki/Araval
# 99             http://tolkiengateway.net/wiki/Araphant
# 104             http://tolkiengateway.net/wiki/Arvedui
# 26   http://tolkiengateway.net/wiki/Eldacar_(King_o...
# 30              http://tolkiengateway.net/wiki/Arantar
# ...

# %%
kings_table[kings_table['name']=='Arvedui']
# Out:
#                                         url  \
# 104  http://tolkiengateway.net/wiki/Arvedui
#
#                                        referrer     name other_names  \
# 104  b'http://tolkiengateway.net/wiki/Araphant'  Arvedui   Last King
#
#                 titles birth_year        rule_start  rule_end  \
# 104  King of Arthedain  T.A. 1864  T.A. 1964 - 1975       NaN
#
#                                         death_year  notable_for
# 104  March T.A. 1975 (aged 111)Icebay of Forochel           NaN
